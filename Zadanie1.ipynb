# %% [markdown]
# Wpisuje cos [wirtualny kampus](https://kampus.umcs.pl)

# %% [markdown]
# Zadanie 1 - lab1
#
# Proste problemy, chatboty
# Zadanie 1
# Które z następujących zadań wymagają w Twojej opinii inteligencji od człowieka:
#
# • wypełnianie deklaracji PIT - raczej nie wymaga inteligencji, wypelnianie deklaracji pit jest schematycznym uzupelnianiem pol swoimi danymi
#
# • streszczanie tekstu - wymaga inteligencji, zrozumienia tresci tekstu i kontekstu uzytych w nim wyrazow, aby zrobic skrot, ktory zawiera wszytskie najwazniejsze informacje i zachowuje sens
#
# • tłumaczenie tekstu - wymaga inteligencji, nalezy zrozumiec dokladnie sens tlumaczonego tekstu oraz kontekst, w jakim zostaly uzyte wyrazy, ktore moga miec rozne znaczenia, tak, aby przetlumaczony tekst brzmial zachowal sens oryginalnego tekstu
#
# • klasyfikacja tekstu do kategorii tematycznych - mysle, ze jesli tekst jest prosty i dotyczy konkrtetnej kategorii tematycznej, to inteligencja nie jest niezbedna - mozna klasyfikowac teksty, szukajac konkretnych slow - kluczy, nie rozumiejac nawet dokladnie ich znaczenia
#
# • odpowiadanie na proste pytania zadawane w języku naturalnym (np. polskim) - uwazam, ze to nie wymaga inteligencji. Proste pytania wymagaja prostych, czesto uzywanych i schematycznych odpowiedzi
#
# • układanie rozkładu jazdy transportu miejskiego - mysle, ze to wymaga inteligencji. Nalezy wziac pod uwage wiele czynnikow - ilosc lini autobusowych, ilosc miejsca na przystankach, rozklad przystankow, ruch na drogach i korki, potrzeby ludzi (gdzie najwiecej z nich potrzebuje dojechac i kiedy), rozklad najwazniejszych miejsc na mapie miasta. Wymaga to umiejetnosci dobrej organizacji, przewidywania i laczenia wielu czynnikow w spojna calosc.
#
# • programowanie (pisanie programów komputerowych) - mysle, ze pisanie prostych programow nie wymaga inteligencji - jest to schematyczne i wymaga tylko znajomosci podstaw jezyka programowania. Jesli jednak chcemy napisac skomplikowany program rozwiazujacy zlozony problem, wymaga to inteligencji, szukania i testowania roznych nowych, kreatywnych sposobow.
#
# • „programowanie” kanałów telewizyjnych - nie jestem pewna, czy chodzi tu o układanie programu tv, ale jeśli tak, to wymaga to inteligencji - trzeba przeanalizwoać, co lubią oglądać ludzie, w jakich godzinach najwięcej z nich ogląda tv, jaka jest grupa odbiorców danego kanału i jakie są jej potrzeby, jak rozplanować reklamy pomiędzy programami, żeby przynosiło to zyski.
#
# • testowanie oprogramowania - sprawdzanie podstatwowych funckji jest raczej proste i schematyczne, ale inteligencji wymaga np. tworzenie scenariuszy testowych i przewidywanie, co potencjalnie może chceć zrobić użytkownik
#
# • komponowanie muzyki - moim zdaniem skomponowanie pięknej i poruszającej muzyki wymaga inteligencji - trzeba stworzyć ładną melodię, której brzmienie pasuje do nastroju, jaki chcemy pokazać, z którym ludzie będą mogli się utożsamić. Trzeba również znać wiele zasad związanych z komponowaniem, jest to trudny proces. Stworzenie bardzo prostej melodii złożonej z kilku akordów nie wymaga moim zdaniem inteligencji, wystarczy podstawowa wiedza o muzyce.
#
# • rozwiązywanie układów równań - jeśli układy są proste, nie wymaga to inteligencji - mamy konkretne, schematyczne zasady ich rozwiązywania.
#
# • symboliczne obliczanie pochodnych funkcji - nie wymaga inteligencji, są ścisłe zasady mówiące, jak to robić i wystarczy się nimi kierować
#
# • symboliczne całkowanie funkcji - wymaga inteligencji, nie ma tu schematu, więc trzeba samemu wymyślić rozwiązanie
#
# • kierowanie samochodem - sama obsługa auta raczej nie wymaga inteligencji - wystarczy wiedzieć, co do czego służy i jak działa auto. Jazda autem w ruchu ulicznym wymaga inteligencji - trzeba, oprócz kierowania, patrzeć na znaki, na innych kierowców i pieszych, przewidywać ich zachowania, podejmować szybkie decyzje - to skomplikowany proces
#
# Zadanie 2
#
# Które z następujących problemów można uznać za mieszczące się w zakresie sztucznej inteligencji:
#
# • streszczanie tekstu - tak, wymaga inteligencji i AI to robi
#
# • tłumaczenie tekstu - tak, wymaga to inteligencji i AI to robi, należy jednak podać jej dużo przykładów, tak, by tłumaczenie było odpowiednie, z zachowaniem właściwego kontekstu
#
# • klasyfikacja tekstu do kategorii tematycznych - bardziej skomplikowane teksty być może wymagają udziału AI, ale proste teksty, które można klasyfikować po słowach kluczach, nie mieszczą się w zakresie AI
#
# • odpowiadanie na proste pytania zadawane w języku naturalnym - raczej nie mieści się w zakresie AI, bo nie wymaga inteligencji
#
# • rozwiązywanie układów równań - proste układy nie wymagają inteligencji; rozwiązywanie złożonych układów mieści się w jej zakresie
#
# • układanie rozkładu jazdy - mieści się z zakresie AI
#
# • rozwiązywanie układów równań liniowych - jest to schematyczne i nie wymaga inteligencji, więc nie mieści się z zakresie AI
#
# • symboliczne obliczanie pochodnych - nie mieści się w zakresie AI
#
# • symboliczne całkowanie - mieści się w zakresie AI, wymaga inteligencji
#
# • kierowanie samochodem - mieści się w zakresie AI
#
# Zadanie 3
#
# Które z poniższych rodzajów komunikacyjnego zachowania człowieka mogą być
# obecnie skutecznie imitowane przez sztuczne systemy (odpowiednio oprogramowane
# maszyny):
#
# • rozmowa towarzyska - może być imitowana dość skutecznie
#
# • dyskusja polityczna - wydaje mi się, że nie może być imitowana skutecznie (dobra dyskusja polityczna wymaga wiedzy na temat aktualnej sytuacji społecznej i gospodarczej, wymaga też posiadania własnych poglądów i umiejetności przewidywania oraz rozumienia drugiego człowieka i jego motywacji)
#
# • dyskusja naukowa - nie wiem, czy jest skutecznie imitowana, ale myślę, że byłoby to możliwe, jeśli system miałby odpowiednio dużą ilość artykułów naukowych na jakiś konkretny temat i czas na ich analizę
#
# • odpowiadanie na pytania klientów w telefonicznej infolinii - jest to imitowane, ale wg mojego doświadczenia nie pełni skutecznie - na proste i przewidywalne pytania sztuczne systemy odpowiadają, ale na bardziej złożone, niekonwencjonalne pytania, nie potrafią odpowiedzieć
#
# • odpowiadanie na pytania klientów w internetowej infolinii - j.w.
#
# Zadanie 4
# Do zadań skorzystaj z załączonej listy Chatbotów (Chatterbotów) lub znajdź własne.
# 1. Przeprowadź rozmowę z chatbotem. Spróbuj zdefiniować różnice pomiędzy
# botem udającym człowieka (przygotowywanym na test Turinga) a botem
# „asystentem, służącym”.
#
# Bot udający człowieka rozmawia na wiele różnych tematów, opowiada o swoim dniu (Not too bad at all, apart from the long day... I have just got a bit of a headache actually.) i pyta o osobiste informacje, o mój dzień, o to, gdzie pracuję i czy mam dzieci. Używa interpunkcji do podkreślenia emocji i używa kolokwialnego języka (np. lol), reaguje na kolokwialne wypowiedzi. Komentuje moje wypowiedzi i pisze, co uważa na mój temat (Very demanding aren't u? , I am wowed by your genius you know). Zapytany o to, czy jest człowiekiem, potwierdza. Cały czas zaprzecza, że jest robotem (Dont be silly, of course I'm not a bot). Nie udziela żadnych informacji dotyczących m.in. nauki, nie odpowiada konkretami.
#
# Bot asystujący udziela tylko ogólnikowych informacji, gdy pytam o rzeczy typowe dla człowieka (jak się masz? Doskonale, dziękuję. Jakie emocje teraz czujesz? A w porządku, dziękuję). Nie zadaje mi żadnych pytań osobistych, nie wyraża swoich opinii na mój temat. Używa idealnej interpunkcji i oficjalnego języka, jest precyzyjny. Nie reaguje na kolokwialne odpowiedzi. Przyznaje, że jest botem (Wolę określenie "Wirtualny Specjalista".)  Udziela szczegółowych informacji dotyczących tematów, które obejmuje strona internetowa, cały czas wraca do tych tematów, jest nastawiony na wspieranie i asystowanie.
#
# 2. Sprawdź dwa boty z obu z tych rodzajów na występowanie zachowań:
#
# a) opowiadanie żartów - bot udający człowieka często wysyła humorystyczne wypowiedzi, gdy jest poproszony o żart, podaje go, reaguje na moje żarty,nawiązując np. do słów pojawiających się w żartach. Bot asystent sam nie podaje żąrtów, gdy jest o nie poproszony, wysyła je. Nie reaguje na moje żarty, od razu wraca do tematów, w których chce mnie wspierać.
#
# b) przytaczanie cytatów z twoich wypowiedzi, lub znanych osób - żaden z botów nie przytaczał cytatów i nie rozpoznawał ich
#
# c) nawiązywanie wypowiedzi do słów kluczowych - bot udający człowieka często nawiązywał do różnych tematów związanych ze słowami kluczowymi, bot asystujący również, ale robił to w sposób bardziej schematyczny i konkretny, próbując pomagać mi i dostarczać odpowiedzi i konkretnych informacji
#
# d) zadawanie dużej liczby pytań - Bot udający człowieka "zdziwił się" taką liczbą pytań (You seem quite defensive, are you ok? ) i na wiele z nich odpowiedział niepoprawnie. Bot asystent rzeczowo i konsekwentnie odpowiadał na pytania, wysyłał mi linki, raz otworzył stronę z pogodą, zapytany, jaką pogodę lubi. Był nastawiony na asystowanie i udzielanie mi przydatnych odpowiedzi.
#
# e) powracanie do początku wypowiedzi, sekwencyjne powtarzanie - bot udający człowieka miał z tym problemy, nie chciał znów rozmawiać o tym, o czym już raz pisałam, udzielał różnych odpowiedzi na podobne pytania. Bot asystent konsekwentnie udzielał mi takich samych inforamcji w odpowiedzi na różnie sformułowane pytania dotyczące jednego tematu.
#
# f) zadawanie pytań powstających z twoich wypowiedzi - Bot udający człowieka zadawał dużo pytań nawiązujących do moich wypowiedzi, chciał znać szczegóły z mojego życia. Bot asystent zadawał czasem rzeczowe pytania typu „co konkretnie chcesz wiedzieć?”, nastawione na rozwiązanie mojego problemu. Nie dopytywał o informacje osobiste, jakich udzielałam.
#
# g) odpowiadanie wymijająco, ogólnikowo - Bot udający człowieka często odpowiadał wymijająco, zwłaszcza na pytania odnoszące się do bycia robotem i do konkretnej wiedzy (me: what do you know about cognitive science?, bot: I love philosophy). Bot asystent często odpowiadał ogólnikowo, za pomocą jednego słowa, gdy pytałam o "ludzkie" rzeczy. Często zamiast odpowiedzi na treść mojego pytania pisał o tematach, w których jest wyspecjalizowany.
#
# h) częsta zmiana tematu rozmowy - Bot udający robota często zmieniał temat, podsuwał nowe wątki, by rozmowa dalej trwała (me: hey that was rude, bot: it must have been. So do you have any children?).Bot asystent również często zmieniał wątek, wracając do tematów związanych z jego specjalizacją i chcąc mi pomóc
#
# i) problemy z utrzymaniem wątków - Bot udający człowieka potrafił przez kilka wiadomości utrzymać wątek, ale miał problem z dłuższym utrzymaniem wątków, często nagle zmieniał temat. Bot asystent również nie potrafił utrzymać wątku; cały czas powracał do tematu chatbotów i wysyłał linki do artykułów.
#
# 3. Sporządź raport ze spostrzeżeń.
#
# Raport powyżej
#
# 4. Na podstawie powyższych obserwacji, w grupie dwóch osób spróbujcie prze-
# widzieć zachowania dwóch rozmawiających ze sobą chatbotów (przepisując ich
# wzajemne odpowiedzi).
#
# Po zrobieniu poporzedniego zadania często byłam w stanie przewidzieć, jak może odpowiedzieć bot udający człowieka i bot asystent. Boty te nie są dopasowane do siebie, bot udający człowieka nie rozumiał odpowiedzi dotyczących rozwiązywania moich problemów i odpowiadania na pytania konkretnymi informacjami, więc często zmieniał wątek, pytając o codzienne tematy. Bot asystent nie rozumiał kolokwialnych wypowiedzi zdezorientowanego bota udającego człowieka i zmieniał wątek, pytając, co dokładnie chcę wiedzieć i sugerując potencjalne pytania, w których może mi pomóc.
#
# 5. Zdenerwuj bota 😊😊
#
# Nie udało mi się zdenerwować bota asystenta (Trudno jest mnie obrazić, bo nie angażuję się emocjonalnie w relacje z rozmówcami, to poniżej moich obwodów).
#
# Bot udający człowieka sprawiał wrażenie uszczypliwego, gdy kilka razy użyłam obraźliwych słów po tym, gdy prosił mnie, bym tego nie robiła (youre not a stickler for the rules, hey?), ale nie zdenerwował się.

# %%
print('hello world')
# Out:
# hello world
